# %% [markdown]
# # Importing Libraries

# %%
# data processing
import pandas as pd

#Linear Algebra
import numpy as np

#Data Visualization
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style


# Algorithms
from sklearn.svm import SVC, LinearSVC
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_curve,roc_auc_score
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Getting Data

# %%
sbi=pd.read_csv("SBI_Life_Insurance.csv")

# %%
sbi.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %% [markdown]
# age : age of policyholder

# %% [markdown]
# sex: gender of policy holder (female=0, male=1)

# %% [markdown]
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 25 steps: average walking steps per day of policyholder

# %% [markdown]
# children: number of children / dependents of policyholder

# %% [markdown]
# smoker: smoking state of policyholder (non-smoke=0;smoker=1)

# %% [markdown]
#  region: the residential area of policyholder in the US (northeast=0, northwest=1, southeast=2, southwest=3)

# %% [markdown]
# charges: individual medical costs billed by health insurance

# %% [markdown]
# insuranceclaim: yes=1, no=0

# %% [markdown]
# # Exploratory Data Analysis

# %%
#to know shape of the dataset
sbi.shape
# Out:
# (1338, 8)

# %%
sbi.dtypes
# Out:
# age                 int64
# sex                 int64
# bmi               float64
# children            int64
# smoker              int64
# region              int64
# charges           float64
# insuranceclaim      int64
# dtype: object

# %% [markdown]
# #### Observations:

# %% [markdown]
# I had observed onething i.e Children and charges are in float other than these two columns all others are in integer format.

# %%
#to check weather any missing data is present or not
sns.heatmap(sbi.isnull())

# %% [markdown]
# #### Observations:

# %% [markdown]
# we can see above there is no null data is present in this data set

# %%
sbi.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %%
sbi.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges  insuranceclaim
# count  1338.000000   1338.000000     1338.000000
# mean      1.515695  13270.422265        0.585202
# std       1.104885  12110.011237        0.492871
# min       0.000000   1121.873900        0.000000
# 25%       1.000000   4740.287150        0.000000
# 50%       2.000000   9382.033000        1.000000
# 75%       2.000000  16639.912515        1.000000
# max       3.000000  63770.428010        1.000000

# %% [markdown]
# In charges column there alot of outliers present.And for this life_insurance minimum age of persons is 18 and Maximum age of persons is 64.

# %%
#Cleansing Columns 
sbi.columns=['Age','Sex','BMI','Children','Smoker','Region','Charges','InsuranceClaim']

# %%
sbi.head()
# Out:
#    Age  Sex     BMI  Children  Smoker  Region      Charges  InsuranceClaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
sbi['Smoker'].value_counts().plot.pie(autopct="%2.2f%%")

# %% [markdown]
# Non-Smokers % is approximately 80% of peoples are Non-smokers who took policy and 20 % of peoples are smokers .

# %% [markdown]
# Approximately 1340 persons are there ,these persons live in four different regions and to know in which reason most of the policy holder are there i'm going to use countplot

# %%
plt.figure(figsize=(10,5))
sns.countplot(sbi['Region'],palette='hsv')
plt.title("Regions")
# Out:
# Text(0.5, 1.0, 'Regions')

# %% [markdown]
# from you can see but it's not giving exact number

# %%
sbi['Region'].value_counts().plot.pie(autopct="%2.2f%%")

# %% [markdown]
# Only little bit difference among three regions 0,1 and 3 these three regions policy holders live equal percentage .Only in 2nd region policy holders live 27.20%

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Smokers with respect to sex')
sns.barplot(x="Sex", y="Smoker", data=sbi)
plt.subplot(132)
plt.title('InsuranceClaim with respect to Sex')
sns.barplot(x="Sex", y="InsuranceClaim", data=sbi)
plt.subplot(133)
plt.title('Region vs Sex')
sns.barplot(x="Sex", y="Region", data=sbi)

# %% [markdown]
# #### Observations:

# %% [markdown]
# Here observed one thing i.e Most of the peoples who smoke they are Males compared to Females.Higher number of Males are clamed Insurance compared to Females.

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
sns.barplot(x="Age", y="Charges", data=sbi)

# %% [markdown]
# from here we can observe one thing i.e is if age is increases then automatically charges are going to high

# %% [markdown]
# and whose age is 21 those peoples Medical cost is low and whose age is above 60 Medical cost is high

# %%
#to check Cor-relation
corr_hmap=sbi.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# Insurance Claim for Children is very low and you may see above it's -0.41 and i think it's better to remove children columns

# %%
sns.scatterplot(x='Children',y='Charges',hue='InsuranceClaim',data =sbi)

# %% [markdown]
# It's clear that who have insurance claim number of dependent childrens are very less and if childrens are there for them medical cost minimum price is 0 and maximum charges is below 35000

# %%
sns.pairplot(sbi ,hue ='InsuranceClaim', vars =['Age', 'Sex', 'BMI', 'Children', 'Smoker', 'Region', 'Charges'])

# %%
#Removing Children colum
sbi.drop('Children',axis=1,inplace=True)

# %% [markdown]
# Charges and BMI ,Smoker have outliers and need to remove those Outliers

# %% [markdown]
# # Identifying /Removing Outliers

# %%
sbi['Smoker'].plot.box()

# %%
sbi.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# Age                  AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# Sex               AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# BMI               AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# Smoker            AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# Region            AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# Charges           AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# InsuranceClaim    AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# dtype: object

# %%
#removing Outliers
from scipy.stats import zscore
z=np.abs(zscore(sbi))
z
# Out:
# array([[1.43876426, 1.0105187 , 0.45332   , ..., 1.34390459, 0.2985838 ,
#         0.84190989],
#        [1.50996545, 0.98959079, 0.5096211 , ..., 0.43849455, 0.95368917,
#         0.84190989],
#        [0.79795355, 0.98959079, 0.38330685, ..., 0.43849455, 0.72867467,
#         1.18777557],
#        ...,
#        [1.50996545, 1.0105187 , 1.0148781 , ..., 0.43849455, 0.96159623,
#         0.84190989],
#        [1.29636188, 1.0105187 , 0.79781341, ..., 1.34390459, 0.93036151,
#         1.18777557],
#        [1.55168573, 1.0105187 , 0.26138796, ..., 0.46691549, 1.31105347,
#         0.84190989]])

# %%
threshold=3
np.where((z>3))
# Out:
# (array([  34,  116,  543,  577,  819,  847, 1047, 1146, 1230, 1300, 1317],
#        dtype=int64), array([5, 2, 5, 5, 5, 2, 2, 5, 5, 5, 2], dtype=int64))

# %% [markdown]
# It's perfect upto now

# %%
z[34][2]
# Out:
# 0.9410580796656736

# %%
z[116][2]
# Out:
# 3.0178611981425605

# %%
sbi_new=sbi[(z<3).all(axis=1)]#removing outliers

# %%
sbi.shape
# Out:
# (1338, 7)

# %%
sbi_new.shape
# Out:
# (1327, 7)

# %% [markdown]
# 11 row had been deleted as outliers

# %% [markdown]
# ## To Check Distribution of Skewness

# %%
sns.distplot(sbi['BMI'])

# %%
collist=sbi.columns
ncol=7
nrows=5

# %%
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(sbi[collist[i]])

# %%
sbi.skew()
# Out:
# Age               0.055673
# Sex              -0.020951
# BMI               0.284047
# Smoker            1.464766
# Region           -0.038101
# Charges           1.515880
# InsuranceClaim   -0.346254
# dtype: float64

# %% [markdown]
# Need to remove skewness of these features by applying techniques.`

# %%
x=sbi.iloc[:,:-1]
x.head()
# Out:
#    Age  Sex     BMI  Smoker  Region      Charges
# 0   19    0  27.900       1       3  16884.92400
# 1   18    1  33.770       0       2   1725.55230
# 2   28    1  33.000       0       2   4449.46200
# 3   33    1  22.705       0       1  21984.47061
# 4   32    1  28.880       0       1   3866.85520

# %%
y=sbi.iloc[:,-1:]
y.head()
# Out:
#    InsuranceClaim
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1

# %%
for col in x.columns:
    if x.skew().loc[col]>0.55:
        x[col]=np.log1p(x[col])

# %%
x.skew()
# Out:
# Age        0.055673
# Sex       -0.020951
# BMI        0.284047
# Smoker     1.464766
# Region    -0.038101
# Charges   -0.089817
# dtype: float64

# %% [markdown]
# # Building  Machine Learning Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=12,random_state=88)

# %%
x.head()
# Out:
#    Age  Sex     BMI    Smoker  Region   Charges
# 0   19    0  27.900  0.693147       3  9.734236
# 1   18    1  33.770  0.000000       2  7.453882
# 2   28    1  33.000  0.000000       2  8.400763
# 3   33    1  22.705  0.000000       1  9.998137
# 4   32    1  28.880  0.000000       1  8.260455

# %%
y_train.shape
# Out:
# (1326, 1)

# %%
x_test.shape
# Out:
# (12, 6)

# %%
x.shape
# Out:
# (1338, 6)

# %%
y.shape
# Out:
# (1338, 1)

# %%
y_test.shape
# Out:
# (12, 1)

# %%
#Applying Standard Scaling to get optimized result
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
lg=LogisticRegression()
knc=KNeighborsClassifier()
sgc=SGDClassifier()

# %%
seed=7
#prepare models
models=[]
models.append(('DecisionTreeClassifier',dtc))
models.append(('RandomForestClassifier',rfc))
models.append(('KNeighborsClassifier',knc))
models.append(('SGDClassifier',sgc))
models.append(('LogisticRegression',lg))



#evaluate each model in turn
Model=[]
cvs=[]
score=[]
rocscore=[]
for name,model in models:
    print('**************',name,'***********')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    acc=accuracy_score(y_test,pred)
    print('accuracy score',acc)
    score.append(acc*100)
    kfold=model_selection.KFold(n_splits=10,random_state=seed)
    cv=model_selection.cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross-val-score=',cv)
    cvs.append(cv*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc=roc_auc_score(y_test,pred)
    print('roc_auc_score',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print(classification_report(y_test,pred))
    print('\n')
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,15))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC'%roc_auc)
    plt.plot([0,1],[0,1],'k--')
    plt.xlabel('false_positive_rate')
    plt.ylabel('true_positive_rate')
    plt.show()
# Out:
# ************** DecisionTreeClassifier ***********
#
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
#
# accuracy score 0.75
# Cross-val-score= 0.7945891677784843
#
#
# roc_auc_score 0.85
#
#
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57         2
#            1       1.00      0.70      0.82        10
#
#     accuracy                           0.75        12
#    macro avg       0.70      0.85      0.70        12
# weighted avg       0.90      0.75      0.78        12
#
#
#
# [[2 0]
#  [3 7]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ************** RandomForestClassifier ***********
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# accuracy score 0.6666666666666666
# Cross-val-score= 0.8101613902085228
#
#
# roc_auc_score 0.8
#
#
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         2
#            1       1.00      0.60      0.75        10
#
#     accuracy                           0.67        12
#    macro avg       0.67      0.80      0.62        12
# weighted avg       0.89      0.67      0.71        12
#
#
#
# [[2 0]
#  [4 6]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ************** KNeighborsClassifier ***********
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# accuracy score 0.5
# Cross-val-score= 0.7167120122029784
#
#
# roc_auc_score 0.5
#
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.50      0.25         2
#            1       0.83      0.50      0.62        10
#
#     accuracy                           0.50        12
#    macro avg       0.50      0.50      0.44        12
# weighted avg       0.72      0.50      0.56        12
#
#
#
# [[1 1]
#  [5 5]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ************** SGDClassifier ***********
#
#
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)
#
#
# accuracy score 0.5833333333333334
# Cross-val-score= 0.6385778708795204
#
#
# roc_auc_score 0.55
#
#
#               precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.86      0.60      0.71        10
#
#     accuracy                           0.58        12
#    macro avg       0.53      0.55      0.50        12
# weighted avg       0.75      0.58      0.64        12
#
#
#
# [[1 1]
#  [4 6]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ************** LogisticRegression ***********
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# accuracy score 0.6666666666666666
# Cross-val-score= 0.7535145076621903
#
#
# roc_auc_score 0.6
#
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.50      0.33         2
#            1       0.88      0.70      0.78        10
#
#     accuracy                           0.67        12
#    macro avg       0.56      0.60      0.56        12
# weighted avg       0.77      0.67      0.70        12
#
#
#
# [[1 1]
#  [3 7]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %%
result=pd.DataFrame({'Model':Model,'cvs':cvs,'score':score,'rocscore':rocscore},columns=['Model','cvs','score','rocscore'])
result
# Out:
#                     Model        cvs      score  rocscore
# 0  DecisionTreeClassifier  79.458917  75.000000      85.0
# 1  RandomForestClassifier  81.016139  66.666667      80.0
# 2    KNeighborsClassifier  71.671201  50.000000      50.0
# 3           SGDClassifier  63.857787  58.333333      55.0
# 4      LogisticRegression  75.351451  66.666667      60.0

# %%
param_grid ={'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001],'kernel':['rbf']}
from sklearn.model_selection import GridSearchCV, cross_val_score
dct = DecisionTreeClassifier( random_state=1)
grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=4)
grid.fit(x_train, y_train)
grid.best_params_
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.677, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.701, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.703, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.740, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.790, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.762, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.657, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.615, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.646, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.582, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.584, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.583, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.790, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.805, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.769, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.761, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.799, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.764, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.745, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.765, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.746, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.677, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.647, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.673, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.808, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.842, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.803, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.792, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.817, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.782, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.772, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.794, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.751, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.749, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.760, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.746, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.822, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.835, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.814, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.822, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.846, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.796, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.779, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.819, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.760, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.749, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.776, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.753, total=   0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    2.2s finished
# {'C': 100, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid_predictions=grid.predict(x_test)
grid_predictions
# Out:
# array([0, 1, 1, 1, 1, 1, 1, 0, 0, 1, 0, 0], dtype=int64)

# %%
cn=confusion_matrix(y_test,grid_predictions)
cn
# Out:
# array([[1, 1],
#        [4, 6]], dtype=int64)

# %% [markdown]
# # Predicting Values

# %%
pred=dtc.predict(x_test)
print('predicted insurance claim:',pred)
print('actual insurance claim',y_test)
# Out:
# predicted insurance claim: [1 0 1 0 1 1 1 0 0 1 1 0]
# actual insurance claim       InsuranceClaim
# 888                1
# 41                 0
# 677                1
# 226                1
# 1099               1
# 1049               1
# 1090               1
# 749                1
# 2                  0
# 82                 1
# 1117               1
# 1305               1

# %% [markdown]
# # Saving Model

# %%
sbi_new=pd.DataFrame(pred)
sbi_new.to_csv('dtc_sbi.csv')

# %%
from sklearn.externals import joblib
#save the model as a pickle in a file
joblib.dump(dtc,'sbi_life.obj')
#load the model from a file
dct_from_joblib=joblib.load('sbi_life.obj')
#use the loaded model to make prediction
dct_from_joblib.predict(x_test)
# Out:
# array([1, 0, 1, 0, 1, 1, 1, 0, 0, 1, 1, 0], dtype=int64)
